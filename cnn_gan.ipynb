# %%
# citations:
# https://stackoverflow.com/questions/46615554/how-to-display-multiple-images-in-one-figure-correctly/46616645
# https://stackoverflow.com/questions/22937589/how-to-add-noise-gaussian-salt-and-pepper-etc-to-image-in-python-with-opencv

# %%
# John Strenio
# CS 510 DL + CV
# Professor Rhodes
# Assignment 5 Exercise 2: GANs

import cv2
import numpy as np
import os
import tensorflow as tf
from tensorflow import keras 
from keras import layers, models
from keras.models import Model
import matplotlib.pyplot as plt

# easy access for parameter adjustments
# these are not independent
b = 64 # smaller seems better DGAN = 32 64 good
lr = 0.0005 # bach size dependent DGAN = 0.0007 0.005 good
noise = True # not always helpful
drop = 0.5 # dis only, better, not on sigmoid DGAN = 0.3
soft = 0.05 # needs to be small
beta = 0.2 # very touchy and helpful DGAN = 0.2
epochs = 100
a = 0.2 # not sure tried a few DGAN = 0.2

# %%
def noise(image):
    row,col,channel= image.shape
    mean = 0
    var = 0.1
    sigma = var**0.5
    gauss = np.random.normal(mean,sigma,(row,col,channel))
    gauss = gauss.reshape(row,col,channel)
    noised = image + gauss
    return noised

# %%
# LOAD AND PREP DATA
# load fashion dset
(imgs_train, labels_train), (imgs_test, labels_test) = tf.keras.datasets.fashion_mnist.load_data()

# normalize then center imgs
imgs_train = (imgs_train / 255) 
imgs_train -= imgs_train.mean()

imgs_train = imgs_train.reshape(len(imgs_train), 28, 28, 1).astype('float32')

# %%
len(imgs_train)
# Out:
# 60000

# %%
# BUILD GAN
# build generator
# 2 conv2dtranpose layers
# input = 6272 -> reshape -> 7x7x128
# output = 28x28x1
# opt adam bin cross ent
gen_model = models.Sequential([
    layers.Dense(7*7*128, input_shape=(100,)),
    layers.BatchNormalization(),
    layers.LeakyReLU(alpha=a), 
    layers.Reshape((7, 7, 128)),
    
    layers.Conv2DTranspose(64, kernel_size=(5, 5), strides=(2, 2), padding='same', use_bias=False),
    layers.BatchNormalization(),
    layers.LeakyReLU(alpha=a),
    
    layers.Conv2DTranspose(1, kernel_size=(5, 5), strides=(2, 2), padding='same', use_bias=False,),
    layers.LeakyReLU(alpha=a),
    layers.Reshape((28, 28, 1))
    ])

print("GENERATOR MODEL SUMMARY:")
gen_model.summary()

# build descriminator
# 2 conv2D layers, input = 28x28x1  -> flatten -> dense
dis_model = models.Sequential([
    layers.Conv2D(256, kernel_size=(5, 5), strides=(2, 2), input_shape=(28, 28, 1), padding='same', use_bias=False,),
    layers.LeakyReLU(alpha=a),

    layers.Conv2D(128, kernel_size=(5, 5), strides=(2, 2), padding='same', use_bias=False,),
    layers.LeakyReLU(alpha=a),

    layers.Conv2D(64, kernel_size=(5, 5), strides=(2, 2), padding='same', use_bias=False,),
    layers.BatchNormalization(),
    layers.LeakyReLU(alpha=a),
    layers.Flatten(),
    
    layers.Dense(1, activation='sigmoid')
    ])

print("DISCRIMINATOR MODEL SUMMARY:")
dis_model.summary()

opt = keras.optimizers.Adam(learning_rate=lr, beta_1=beta)
dis_model.compile(optimizer=opt, loss='binary_crossentropy', metrics='accuracy')

# concatenate models
# freeze descriminator weights COMPILE DIS FIRST
dis_model.trainable=False

gan_model = models.Sequential()
gan_model.add(gen_model)
gan_model.add(dis_model)

print("GAN MODEL SUMMARY:")
gan_model.summary()

opt2 = keras.optimizers.Adam(learning_rate=lr, beta_1=beta)
gan_model.compile(optimizer=opt2, loss='binary_crossentropy', metrics='accuracy')
# Out:
# GENERATOR MODEL SUMMARY:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6272)              633472
# _________________________________________________________________
# batch_normalization (BatchNo (None, 6272)              25088
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 64)        204800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 1)         1600
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 28, 28, 1)         0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 28, 28, 1)         0
# =================================================================
# Total params: 865,216
# Trainable params: 852,544
# Non-trainable params: 12,672
# _________________________________________________________________
# DISCRIMINATOR MODEL SUMMARY:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 14, 14, 256)       6400
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 128)         819200
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          204800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 1,031,681
# Trainable params: 1,031,553
# Non-trainable params: 128
# _________________________________________________________________
# GAN MODEL SUMMARY:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 28, 28, 1)         865216
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 1031681
# =================================================================
# Total params: 1,896,897
# Trainable params: 852,544
# Non-trainable params: 1,044,353
# _________________________________________________________________

# %%
def save_plot(epoch):
    fig, axs = plt.subplots(2, 2)
    cnt = 0
    for i in range(2):
        for j in range(2):
            axs[i,j].imshow(gen_model(np.random.normal(0, 1, (1,100)))[0])
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("imgs/cnn_gan%d.png" % epoch)

# %%
# TRAIN GAN

# train gan and descriminator for 100 epochs using custom training loop
dis_loss = []
gen_loss = []
for epoch in range(epochs):
    # generate B random vectors 
    gen_vecs = np.random.normal(0, 1, (b, 100)) 
    #gen_vecs.reshape()

    # pass vectors through generator to create "images"
    gen_imgs = np.array(gen_model.predict(gen_vecs))
    #gen_imgs = np.expand_dims(gen_imgs, axis=3)

    # concatenate fake and real imgs and add noise
    all_imgs = np.concatenate([gen_imgs, imgs_train[(epoch*b):((epoch+1)*b)]])

    if noise:
        for img in all_imgs:
            img = noise(img)

    # soft 0 labels (fake)
    zero_labels = np.zeros(b) + soft

    #soft 1 labels (real)
    one_labels = np.ones(b) - soft

    labels = np.concatenate([zero_labels, one_labels])
    img_label_tuples = [(all_imgs[i], labels[i]) for i in range(2*b)]

    # shuffle imgs
    np.random.shuffle(img_label_tuples)
    all_imgs = np.array([tupl[0] for tupl in img_label_tuples])
    labels = np.array([tupl[1] for tupl in img_label_tuples])

    # unfreeze discriminator weights
    dis_model.trainable=True

    # train discriminator on all images
    dis_out = dis_model.train_on_batch(all_imgs, labels)
    dis_loss.append(dis_out[0])

    # train gen
    # freeze discriminator weights
    dis_model.trainable=False

    # generate B noise samples
    gen_vecs = np.random.normal(0, 1, (b, 100))

    # create soft labels all with 1 (claiming the imgs are real)
    gen_labels = np.ones(b) - soft

    # pass noise samples through full gan
    gan_out = gan_model.train_on_batch(gen_vecs, gen_labels)
    gen_loss.append(gan_out[0])

    print('training step ' + str(epoch) + ' GLoss: ' + str(round(gan_out[0],2)) + ' Acc: ' 
    + str(round(gan_out[1],2)) + ' DLoss: ' + str(round(dis_out[0],2)) + ' Acc: ' + str(round(dis_out[1],2)))

    if epoch % 10 == 0:
        save_plot(epoch)
# Out:
# training step 0 GLoss: 0.64 Acc: 0.0 DLoss: 0.72 Acc: 0.0
# training step 1 GLoss: 0.61 Acc: 0.0 DLoss: 0.34 Acc: 0.0
# training step 2 GLoss: 0.64 Acc: 0.0 DLoss: 0.25 Acc: 0.0
# training step 3 GLoss: 0.63 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 4 GLoss: 0.6 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 5 GLoss: 0.62 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 6 GLoss: 0.61 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 7 GLoss: 0.62 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 8 GLoss: 0.62 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 9 GLoss: 0.67 Acc: 0.0 DLoss: 0.23 Acc: 0.0
# training step 10 GLoss: 0.59 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 11 GLoss: 0.8 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 12 GLoss: 0.65 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 13 GLoss: 0.71 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 14 GLoss: 0.63 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 15 GLoss: 0.88 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 16 GLoss: 0.55 Acc: 0.0 DLoss: 0.23 Acc: 0.0
# training step 17 GLoss: 0.82 Acc: 0.0 DLoss: 0.25 Acc: 0.0
# training step 18 GLoss: 0.76 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 19 GLoss: 0.64 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 20 GLoss: 0.64 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 21 GLoss: 0.61 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 22 GLoss: 0.63 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 23 GLoss: 0.56 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 24 GLoss: 0.81 Acc: 0.0 DLoss: 0.24 Acc: 0.0
# training step 25 GLoss: 0.75 Acc: 0.0 DLoss: 0.25 Acc: 0.0
# training step 26 GLoss: 0.72 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 27 GLoss: 0.69 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 28 GLoss: 0.7 Acc: 0.0 DLoss: 0.23 Acc: 0.0
# training step 29 GLoss: 0.58 Acc: 0.0 DLoss: 0.23 Acc: 0.0
# training step 30 GLoss: 1.08 Acc: 0.0 DLoss: 0.26 Acc: 0.0
# training step 31 GLoss: 0.74 Acc: 0.0 DLoss: 0.29 Acc: 0.0
# training step 32 GLoss: 0.52 Acc: 0.0 DLoss: 0.24 Acc: 0.0
# training step 33 GLoss: 0.74 Acc: 0.0 DLoss: 0.25 Acc: 0.0
# training step 34 GLoss: 0.74 Acc: 0.0 DLoss: 0.23 Acc: 0.0
# training step 35 GLoss: 0.66 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 36 GLoss: 0.63 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 37 GLoss: 0.58 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 38 GLoss: 0.52 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 39 GLoss: 0.55 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 40 GLoss: 0.57 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 41 GLoss: 0.48 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 42 GLoss: 0.51 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 43 GLoss: 0.52 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 44 GLoss: 0.64 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 45 GLoss: 0.47 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 46 GLoss: 0.81 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 47 GLoss: 0.56 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 48 GLoss: 0.72 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 49 GLoss: 0.48 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 50 GLoss: 0.59 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 51 GLoss: 0.51 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 52 GLoss: 0.52 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 53 GLoss: 0.52 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 54 GLoss: 0.59 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 55 GLoss: 0.56 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 56 GLoss: 0.62 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 57 GLoss: 0.6 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 58 GLoss: 0.58 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 59 GLoss: 0.6 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 60 GLoss: 0.64 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 61 GLoss: 0.75 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 62 GLoss: 0.59 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 63 GLoss: 0.78 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 64 GLoss: 0.61 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 65 GLoss: 0.6 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 66 GLoss: 0.63 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 67 GLoss: 0.58 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 68 GLoss: 0.57 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 69 GLoss: 0.5 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 70 GLoss: 0.56 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 71 GLoss: 0.49 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 72 GLoss: 0.53 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 73 GLoss: 0.5 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 74 GLoss: 0.52 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 75 GLoss: 0.46 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 76 GLoss: 0.4 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 77 GLoss: 0.51 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 78 GLoss: 0.42 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 79 GLoss: 0.4 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 80 GLoss: 0.46 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 81 GLoss: 0.39 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 82 GLoss: 0.43 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 83 GLoss: 0.34 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 84 GLoss: 0.44 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 85 GLoss: 0.34 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 86 GLoss: 0.37 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 87 GLoss: 0.32 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 88 GLoss: 0.35 Acc: 0.0 DLoss: 0.2 Acc: 0.0
# training step 89 GLoss: 0.35 Acc: 0.0 DLoss: 0.21 Acc: 0.0
# training step 90 GLoss: 0.3 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 91 GLoss: 0.48 Acc: 0.0 DLoss: 0.23 Acc: 0.0
# training step 92 GLoss: 0.27 Acc: 0.0 DLoss: 0.25 Acc: 0.0
# training step 93 GLoss: 0.49 Acc: 0.0 DLoss: 0.26 Acc: 0.0
# training step 94 GLoss: 0.33 Acc: 0.0 DLoss: 0.25 Acc: 0.0
# training step 95 GLoss: 0.31 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 96 GLoss: 0.32 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 97 GLoss: 0.32 Acc: 0.0 DLoss: 0.22 Acc: 0.0
# training step 98 GLoss: 0.32 Acc: 0.0 DLoss: 0.23 Acc: 0.0
# training step 99 GLoss: 0.36 Acc: 0.0 DLoss: 0.24 Acc: 0.0

# %%
plt.plot(range(epochs), gen_loss, label = "gen loss")
plt.plot(range(epochs), dis_loss, label = "dis loss")
plt.xlabel('epoch')
# Set the y axis label of the current axis.
plt.ylabel('loss')
# Set a title of the current axes.
plt.title('losses')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
save_plot(99)
